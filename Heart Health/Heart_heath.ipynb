# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/shiva/Downloads/heart-disease-uci/heart.csv")

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe(include ="all")
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.loc[df['age'] == 55]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 75    55    0   1       135   250    0        0      161      0      1.4
# 114   55    1   1       130   262    0        1      155      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 180   55    1   0       132   353    0        1      132      1      1.2
# 221   55    1   0       140   217    0        1      111      1      5.6
# 232   55    1   0       160   289    0        0      145      1      0.8
# 266   55    0   0       180   327    0        2      117      1      3.4
# 289   55    0   0       128   205    0        2      130      1      2.0
#
#      slope  ca  thal  target
# 75       1   0     2       1
# 114      2   0     2       1
# 161      2   0     2       1
# 180      1   1     3       0
# 221      0   0     3       0
# 232      1   1     3       0
# 266      1   0     2       0
# 289      1   1     3       0

# %%
df.dropna(subset = ['age'], inplace = True)

# %%
df.dropna(subset = ['chol'], inplace = True)

# %%
df.describe(include = 'all')
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.count()
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
df['age'].count()
# Out:
# 303

# %%
binwidth = int((max(df['age'])-min(df['age']))/4)
bins = range (min(df['age']),max(df['age']),binwidth)
df['Bined age']= pd.cut(df['age'],bins,labels=('low','Medium','High'))
# Out:
#   File "<ipython-input-23-b9080adec049>", line 3
#     df['Bined age', header = 'new_age']= pd.cut(df['age'],bins,labels=('low','Medium','High'))
#                            ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

# %%
df['Bined age'].head(5)
# Out:
# 0    High
# 1     low
# 2     low
# 3    High
# 4    High
# Name: Bined age, dtype: category
# Categories (3, object): [low < Medium < High]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.boxplot(x = 'cp', y='age', data=df)

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.boxplot(x = 'age', y='chol', data=df)

# %%
import matplotlib.pyplot as plt

# %%
y = df['thalach']
x = df['age']
plt.scatter(x,y)
plt.title('Scatetr plot of Age Vs fasting blood sugar')
# Out:
# Text(0.5, 1.0, 'Scatetr plot of Age Vs fasting blood sugar')

# %%
df_group = df.groupby('age')

# %%
df_group.first()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 29     1   1       130   204    0        0      202      0      0.0      2
# 34     1   3       118   182    0        0      174      0      0.0      2
# 35     0   0       138   183    0        1      182      0      1.4      2
# 37     1   2       130   250    0        1      187      0      3.5      0
# 38     1   2       138   175    0        1      173      0      0.0      2
# 39     1   2       140   321    0        0      182      0      0.0      2
# 40     1   3       140   199    0        1      178      1      1.4      2
# 41     0   1       130   204    0        0      172      0      1.4      2
# 42     1   0       140   226    0        1      178      0      0.0      2
# 43     1   0       150   247    0        1      171      0      1.5      2
# 44     1   1       120   263    0        1      173      0      0.0      2
# ...

# %%
df_group['sex'].count()
# Out:
# age
# 29     1
# 34     2
# 35     4
# 37     2
# 38     3
# 39     4
# 40     3
# 41    10
# 42     8
# 43     8
# 44    11
# 45     8
# 46     7
# 47     5
# 48     7
# 49     5
# 50     7
# 51    12
# 52    13
# 53     8
# 54    16
# 55     8
# 56    11
# 57    17
# 58    19
# 59    14
# 60    11
# 61     8
# 62    11
# 63     9
# 64    10
# 65     8
# 66     7
# 67     9
# 68     4
# 69     3
# 70     4
# 71     3
# 74     1
# 76     1
# 77     1
# Name: sex, dtype: int64

# %%
df['chol'] = (df['chol']-df['chol'].mean())/df['chol'].std()

# %%
sns.regplot(x='chol', y='age' ,data = df)
plt.ylim(20,80)
# Out:
# (20, 80)

# %%
from scipy import stats

# %%
pearson_coef, p_value=stats.pearsonr(df['chol'], df['age'])

# %%
pearson_coef
# Out:
# 0.21367795655956187

# %%
p_value
# Out:
# 0.00017862864341449024

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(df['age'],df ['chol'],test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
x= x_train
y= y_train
lm.fit([x], [y])
yhat = lm.predict([x])

# %%
#We will practise how can we use 'lineplot'
df.chol.plot(kind="line",color="green",label="chol",grid=True,linestyle=":")
df.thalach.plot(kind="line",color="purple",label="thalach",grid=True)
df.age.plot(kind="line",color="pink",label="age",grid=True)
df.trestbps.plot(kind="line",color="orange",label="trestbps",grid=True)
plt.legend(loc="upper right") #legend: puts feature label into plot
plt.xlabel("indexes")
plt.ylabel("Features")
plt.title("Heart Diseases")
plt.show()
