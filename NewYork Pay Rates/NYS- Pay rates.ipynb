# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/shiva/Downloads/nys-salary-information-for-the-public-sector/salary-information-for-state-authorities.csv")
# Out:
# C:\Users\shiva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (2,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61c774354124> in <module>
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
df.tail(50)
# Out:
#                                     Authority Name Fiscal Year End Date  \
# 640899  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640900  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640901  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640902  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640903  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640904  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640905  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640906  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640907  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640908  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640909  Westchester County Health Care Corporation  2016-12-31T00:00:00
# 640910  Westchester County Health Care Corporation  2016-12-31T00:00:00
# ...

# %%
df.loc[df['Paid By Another Entity'] != "N"]
# Out:
#                                   Authority Name Fiscal Year End Date  \
# 36264    Homeless Housing Assistance Corporation  2011-03-31T00:00:00
# 36265    Homeless Housing Assistance Corporation  2012-03-31T00:00:00
# 36266    Homeless Housing Assistance Corporation  2013-03-31T00:00:00
# 36267    Homeless Housing Assistance Corporation  2014-03-31T00:00:00
# 36268    Homeless Housing Assistance Corporation  2015-03-31T00:00:00
# 36269    Homeless Housing Assistance Corporation  2016-03-31T00:00:00
# 36270             Housing Trust Fund Corporation  2011-03-31T00:00:00
# 36271             Housing Trust Fund Corporation  2011-03-31T00:00:00
# 36272             Housing Trust Fund Corporation  2011-03-31T00:00:00
# 36273             Housing Trust Fund Corporation  2011-03-31T00:00:00
# 36274             Housing Trust Fund Corporation  2011-03-31T00:00:00
# 36275             Housing Trust Fund Corporation  2011-03-31T00:00:00
# ...

# %%
df.loc[df['Paid by State or Local Government'] != "NaN"]
# Out:
#                                            Authority Name  \
# 0       Agriculture and New York State Horse Breeding ...
# 1       Agriculture and New York State Horse Breeding ...
# 2       Agriculture and New York State Horse Breeding ...
# 3       Agriculture and New York State Horse Breeding ...
# 4       Agriculture and New York State Horse Breeding ...
# 5       Agriculture and New York State Horse Breeding ...
# 6       Agriculture and New York State Horse Breeding ...
# 7       Agriculture and New York State Horse Breeding ...
# 8       Agriculture and New York State Horse Breeding ...
# 9       Agriculture and New York State Horse Breeding ...
# 10      Agriculture and New York State Horse Breeding ...
# 11                     Albany Convention Center Authority
# 12                     Albany Convention Center Authority
# 13                     Albany Convention Center Authority
# 14                     Albany Convention Center Authority
# ...

# %%
df.drop(['Paid By Another Entity', 'Paid by State or Local Government'],axis=1,inplace = True)

# %%
df.dropna(subset=['Total Compensation'],inplace = True)

# %%
df[df['Total Compensation'].notnull()]
# Out:
#                                            Authority Name  \
# 0       Agriculture and New York State Horse Breeding ...
# 1       Agriculture and New York State Horse Breeding ...
# 2       Agriculture and New York State Horse Breeding ...
# 3       Agriculture and New York State Horse Breeding ...
# 4       Agriculture and New York State Horse Breeding ...
# 5       Agriculture and New York State Horse Breeding ...
# 6       Agriculture and New York State Horse Breeding ...
# 7       Agriculture and New York State Horse Breeding ...
# 8       Agriculture and New York State Horse Breeding ...
# 9       Agriculture and New York State Horse Breeding ...
# 10      Agriculture and New York State Horse Breeding ...
# 11                     Albany Convention Center Authority
# 12                     Albany Convention Center Authority
# 13                     Albany Convention Center Authority
# 14                     Albany Convention Center Authority
# ...

# %%
df[df['Has Employees'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Authority Name, Fiscal Year End Date, Has Employees, Last Name, Middle Initial, First Name, Title, Group, Department, Pay Type, Exempt Indicator, Base Annualized Salary, Actual Salary Paid, Overtime Paid, Performance Bonus, Extra Pay, Other Compensation, Total Compensation]
# Index: []

# %%
df.drop(['Has Employees'],axis=1,inplace = True)

# %%
df.head(5)
# Out:
#                                       Authority Name Fiscal Year End Date  \
# 0  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 1  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 2  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 3  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
# 4  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
#
#   Last Name Middle Initial First Name               Title  \
# 0   Johnson              M  Christine          Controller
# 1     Goold              G      Peter  Executive Director
# 2    Gordon            NaN        Tim  Executive Director
# 3  Mullaney            NaN    Michael  Executive Director
# 4    Gordon            NaN    Timothy  Executive Director
#
#                      Group Department Pay Type Exempt Indicator  \
# 0  Administrative/Clerical        NaN       FT                N
# ...

# %%
df.loc[df['Pay Type'] = "PT" ]
# Out:
#   File "<ipython-input-13-955f1ab63456>", line 1
#     df.loc[df['Pay Type'] = "PT" ]
#                           ^
# SyntaxError: invalid syntax

# %%
df.count()
# Out:
# Authority Name            640932
# Fiscal Year End Date      640932
# Last Name                 640932
# Middle Initial            527398
# First Name                640932
# Title                     640932
# Group                     640932
# Department                635120
# Pay Type                  640932
# Exempt Indicator          640932
# Base Annualized Salary    640932
# Actual Salary Paid        640932
# Overtime Paid             640932
# Performance Bonus         640932
# Extra Pay                 640932
# Other Compensation        640932
# Total Compensation        640932
# dtype: int64

# %%
df[['Pay Type']].count()
# Out:
# Pay Type    640932
# dtype: int64

# %%
df.dtypes
# Out:
# Authority Name             object
# Fiscal Year End Date       object
# Last Name                  object
# Middle Initial             object
# First Name                 object
# Title                      object
# Group                      object
# Department                 object
# Pay Type                   object
# Exempt Indicator           object
# Base Annualized Salary    float64
# Actual Salary Paid        float64
# Overtime Paid             float64
# Performance Bonus         float64
# Extra Pay                 float64
# Other Compensation        float64
# Total Compensation        float64
# dtype: object

# %%
# Changing the datatype of the compensation
# df['Total Compensation']=df['Total Compensation'].astype('int')

# %%
df.describe(include ='all')
# Out:
#                                Authority Name Fiscal Year End Date Last Name  \
# count                                  640932               640932    640932
# unique                                     46                   24     80496
# top     Metropolitan Transportation Authority  2014-12-31T00:00:00  Williams
# freq                                   450713                95778      3898
# mean                                      NaN                  NaN       NaN
# std                                       NaN                  NaN       NaN
# min                                       NaN                  NaN       NaN
# 25%                                       NaN                  NaN       NaN
# 50%                                       NaN                  NaN       NaN
# 75%                                       NaN                  NaN       NaN
# max                                       NaN                  NaN       NaN
#
# ...

# %%
df.head(5)
# Out:
#                                       Authority Name Fiscal Year End Date  \
# 0  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 1  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 2  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 3  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
# 4  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
#
#   Last Name Middle Initial First Name               Title  \
# 0   Johnson              M  Christine          Controller
# 1     Goold              G      Peter  Executive Director
# 2    Gordon            NaN        Tim  Executive Director
# 3  Mullaney            NaN    Michael  Executive Director
# 4    Gordon            NaN    Timothy  Executive Director
#
#                      Group Department Pay Type Exempt Indicator  \
# 0  Administrative/Clerical        NaN       FT                N
# ...

# %%
import pandas as pd

# %%
# One hot encoding
# Converting Categorical variables into numerical variables
pd.get_dummies(df['Pay Type'])
# Out:
#         FT  PT
# 0        1   0
# 1        1   0
# 2        1   0
# 3        1   0
# 4        1   0
# 5        1   0
# 6        1   0
# 7        1   0
# 8        1   0
# 9        1   0
# 10       1   0
# 11       1   0
# 12       1   0
# 13       1   0
# 14       1   0
# 15       1   0
# 16       1   0
# 17       1   0
# 18       1   0
# 19       1   0
# 20       1   0
# 21       1   0
# 22       1   0
# 23       0   1
# 24       0   1
# 25       0   1
# 26       0   1
# 27       0   1
# 28       0   1
# 29       0   1
# ...     ..  ..
# 640919   1   0
# 640920   1   0
# 640921   1   0
# 640922   1   0
# 640923   1   0
# 640924   1   0
# 640925   1   0
# 640926   1   0
# 640927   1   0
# 640928   1   0
# 640929   1   0
# 640930   0   1
# 640931   1   0
# 640932   1   0
# 640933   1   0
# 640934   1   0
# 640935   1   0
# 640936   1   0
# 640937   1   0
# 640938   1   0
# 640939   1   0
# 640940   1   0
# 640941   1   0
# 640942   1   0
# 640943   1   0
# 640944   1   0
# ...

# %%
# Binning of Data based on total compensation
# binwidth = int((max(df['Total Compensation'])-min(df['Total Compensation']))/4)
# bins = range (min(df['Total Compensation']),max(df['Total Compensation']),binwidth)
# df['Bined Compensation']= pd.qcut(df['Total Compensation'],bins,labels=('low','Medium','High'))
df.head(5)
# Out:
#                                       Authority Name Fiscal Year End Date  \
# 0  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 1  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 2  Agriculture and New York State Horse Breeding ...  2011-12-31T00:00:00
# 3  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
# 4  Agriculture and New York State Horse Breeding ...  2012-12-31T00:00:00
#
#   Last Name Middle Initial First Name               Title  \
# 0   Johnson              M  Christine          Controller
# 1     Goold              G      Peter  Executive Director
# 2    Gordon            NaN        Tim  Executive Director
# 3  Mullaney            NaN    Michael  Executive Director
# 4    Gordon            NaN    Timothy  Executive Director
#
#                      Group Department Pay Type Exempt Indicator  \
# 0  Administrative/Clerical        NaN       FT                N
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
y = df['Total Compensation']
x = df['Base Annualized Salary']
plt.scatter(x,y)
plt.title('Scatter Plot of Bas Salary Vs Compensation')
plt.gcf().set_size_inches((20,20))
plt.xlabel('Base Salary')
plt.ylabel('Total Compensation')
# Out:
# Text(0, 0.5, 'Total Compensation')

# %%
# Relation between Performance and salary
y = df['Total Compensation']
x = df['Performance Bonus']
plt.scatter(x,y)
plt.title('Scatter Plot of Bas Salary Vs Compensation')
plt.gcf().set_size_inches((20,20))
plt.xlabel('Performance Bonus')
plt.ylabel('Total Compensation')
# Out:
# Text(0, 0.5, 'Total Compensation')

# %%
sns.boxplot(x = 'Authority Name', y = 'Total Compensation', data= df )

# %%
# Grouping of Data in terms of Authority Name
df_group = df.groupby('Authority Name')

# %%
df_group.first()
# Out:
#                                                    Fiscal Year End Date  \
# Authority Name
# Agriculture and New York State Horse Breeding D...  2011-12-31T00:00:00
# Albany Convention Center Authority                  2011-12-31T00:00:00
# Battery Park City Authority                         2011-10-31T00:00:00
# Buffalo Fiscal Stability Authority                  2011-06-30T00:00:00
# Capital District Transportation Authority           2011-03-31T00:00:00
# Central New York Regional Transportation Authority  2011-03-31T00:00:00
# Development Authority of the North Country          2011-03-31T00:00:00
# Dormitory Authority of the State of New York        2011-03-31T00:00:00
# Environmental Facilities Corporation                2011-03-31T00:00:00
# Erie County Fiscal Stability Authority              2011-12-31T00:00:00
# Erie County Medical Center Corporation              2011-12-31T00:00:00
# Housing Trust Fund Corporation                      2011-03-31T00:00:00
# ...

# %%
# Relation between Authority and Compensation
y = df['Total Compensation']
x = df['Authority Name']
plt.scatter(x,y)
plt.title('Scatter Plot of Bas Salary Vs Compensation')
plt.gcf().set_size_inches((40,20))
plt.xlabel('Authority Name')
plt.ylabel('Total Compensation')
# Out:
# Text(0, 0.5, 'Total Compensation')

# %%
# Pivot Table
df_pivot = df_group.pivot(index='Authority Name', Column='Total Compensation', values = 'Group' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-e88b238d3521> in <module>
#       1 # Pivot Table
# ----> 2 df_pivot = df_group.pivot(index='Authority Name', Column='Total Compensation', values = 'Group' )
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
# ...

# %%
# sns.regplot(x='Authority Name',y='Total Compensation',data = df)
# plt.ylim(0,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
# Linear Regression
x = df[['Base Annualized Salary']]
y = df[['Total Compensation']]
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yhat = lm.predict(1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-cfc23863abce> in <module>
# ----> 1 yhat = lm.predict(1000)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# ...

# %%
sns.regplot(x='Base Annualized Salary',y='Total Compensation',data = df)
plt.ylim(0,)
# Out:
# C:\Users\shiva\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 2644230.7022482473)

# %%
# Multiple Regression
z = df[['Base Annualized Salary','Actual Salary Paid','Overtime Paid','Performance Bonus','Extra Pay','Other Compensation']]
lm.fit(z,df['Total Compensation'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
zhat = lm.predict(df['Total Compensation'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-e1af14992808> in <module>
# ----> 1 zhat = lm.predict(df['Total Compensation'])
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# ...

# %%
sns.residplot (df['Base Annualized Salary'],df['Total Compensation'])

# %%
df.to_csv('C:/Users/shiva/Downloads/salary-information-for-state-authorities.csv')
